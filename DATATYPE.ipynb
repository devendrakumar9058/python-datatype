# %% [markdown]
# DATATYPE
# 1.INTEGER
# 2.STRING
# 3.FLOAT
# 4.BOOLEAN

# %%
#integer
a=55
print(a)

#floating point number
a=45.5
print(type(a))

#string
a="dEVENDRA KUMAR"
print(a)

#boolean
a=True
print(a)
#only output can be true or false

#complex number=3+4i
# Out:
# 55
# <class 'float'>
# dEVENDRA KUMAR
# True
